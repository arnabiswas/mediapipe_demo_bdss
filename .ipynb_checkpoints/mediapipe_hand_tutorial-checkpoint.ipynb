# %% [markdown]
# # Mediapipe hand detection demo

# %% [markdown]
# Detects hand landmarks and draws them on the image

# %%
# Let's import all the python libraries we need for this demo
import mediapipe as mp
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading an input image

# %% [markdown]
# Let's read in some images of people with hand poses to run hand detection. We provide some images from the internet in the hands folder.

# %%
# %ls hands/
# Out:
# kante.jpg  neymar.jpg  rapinoe.jpg  victory.jpg

# %%
#let's read one of them
frame = cv2.imread('hands/victory.jpg')

# %% [markdown]
# ### Fitting the hand model to our image

# %%
#setting up the mediapipe hand detection model parameters
mpHands = mp.solutions.hands

# You can set the max number of hands in the max_num_hands variable below
#You can also change confidence to increase / decrease sesitivity of the model
hands = mpHands.Hands(static_image_mode=False,
                      max_num_hands=2,
                      min_detection_confidence=0.5,
                      min_tracking_confidence=0.5)
mpDraw = mp.solutions.drawing_utils

# %% [markdown]
# ### Drawing the detected hands onto the image

# %%
imgRGB = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
results = hands.process(imgRGB)

if results.multi_hand_landmarks:
    for handLms in results.multi_hand_landmarks:
        for id, lm in enumerate(handLms.landmark):
            h, w, c = frame.shape
            cx, cy = int(lm.x *w), int(lm.y*h)
            cv2.circle(frame, (cx,cy), 3, (255,0,255), cv2.FILLED)

        mpDraw.draw_landmarks(frame, handLms, mpHands.HAND_CONNECTIONS)

# %% [markdown]
# ## Displaying the resutls

# %%
rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.figure(dpi=300)
plt.imshow(rgb_frame)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# Change the input image to another file and run the code again.

# %% [markdown]
# #### Optional: Use wget to download another image of your choice and run mediapipe hand detection
